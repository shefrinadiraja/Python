# %%
import random

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
# make a game use the while loop
# computer will generate a guess number if you will enter same number you won else you could not guess

# %%
import random

x=random.randint(1,100)
for i in range(8):
    y= input(f'enter the value: chances left:{7-i}')
    y=int(y)
    if x==y:
        print('the answer is correct')
        break
    else:
        if x >y:
            print(' you number is small')
        else:
            print(' upi number is bigger')
print(x,y)
# Out:
#  upi number is bigger
#  you number is small
#  upi number is bigger
#  upi number is bigger
#  upi number is bigger
# the answer is correct
# 26 26

# %%
import function_file

# %%
function_file.add_2_numbers(10,20)
# Out:
# 30

# %%
import datetime

# %%
t1 = datetime.datetime.now()

# %%
pip install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 44.1 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy 


numpy.mean([23,5,454,54])
# Out:
# np.float64(134.0)

# %%
pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 32.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 38.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 43.7 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib

# %%
help(matplotlib)
# Out:
# Help on package matplotlib:
#
# NAME
#     matplotlib - An object-oriented plotting library.
#
# DESCRIPTION
#     A procedural interface is provided by the companion pyplot module,
#     which may be imported directly, e.g.::
#
#         import matplotlib.pyplot as plt
#
#     or using ipython::
#
#         ipython
#
#     at your terminal, followed by::
#
#         In [1]: %matplotlib
#         In [2]: import matplotlib.pyplot as plt
#
#     at the ipython shell prompt.
#
#     For the most part, direct use of the explicit object-oriented library is
#     encouraged when programming; the implicit pyplot interface is primarily for
#     working interactively. The exceptions to this suggestion are the pyplot
#     functions `.pyplot.figure`, `.pyplot.subplot`, `.pyplot.subplots`, and
#     `.pyplot.savefig`, which can greatly simplify scripting.  See
#     :ref:`api_interfaces` for an explanation of the tradeoffs between the implicit
#     and explicit interfaces.
#
# ...

# %%
x = numpy.arange(1,10,0.01)
y = numpy.sin(x)

# %%
import matplotlib.pyplot as plt


plt.plot(x,y)
